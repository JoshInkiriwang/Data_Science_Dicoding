# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## **Gathering Data**

# %%
import pandas as pd

# %%
customer_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/customers.csv')

customer_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
order_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/orders.csv');

order_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
product_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/products.csv')

product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/sales.csv')

sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# ## Assessing Data and Cleaning Data

# %% [markdown]
# #### Menilai Customer_df

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
customer_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
print("Jumlah duplikasi : ", customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi :  6

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# #### Hasil Penilaian / Assesment customer_df
# Masalah yang ada pada **customer_df**
#
# *   18 data pada kolom gender yang NULL / Kosong
# *   6 buah data duplikasi
# *   kolom umur yang tidak akurat, dimana umur maksimal 700

# %% [markdown]
# ### Membersihkan customer_df

# %% [markdown]
# #### Menghapus data yang duplikat

# %%
# Menghapus data yang duplikat
customer_df.drop_duplicates(inplace=True)

print('Jumlah duplikasi :', customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi : 0

# %% [markdown]
# #### Mengisi Missing Value

# %%
# Mengambil data yang memiliki missing value
customer_df[customer_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# Berdasarkan gambar di atas, dapat dilihat bahwa baris data tersebut masih mengandung banyak informasi penting sehingga sayang jika langsung dibuang. Oleh karena itu, pada kasus ini, kita akan menggunakan metode imputation untuk menangani missing value.

# %%
# Gunakanlah method value_counts()untuk mengidentifikasi nilai yang dominan.
customer_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %% [markdown]
# Dominan data pada kategori gender yaitu Prefer not to say. Nilai inilah yang selanjutnya akan kita gunakan sebagai pengganti missing value. Proses penggantian ini dapat dilakukan menggunakan method fillna()

# %%
customer_df.fillna(value='Prefer not to say', inplace=True)

# cek apakah masih ada kolom data yang NaN
customer_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %% [markdown]
# #### Mencari inaccurate data

# %%
customer_df[customer_df.age == customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# kita bisa berasumsi bahwa inaccurate value tersebut terjadi karena human error sehingga kelebihan memasukkan nilai nol. Oleh karena itu, gantilah dengan nilai 70. Proses ini dilakukan dengan memanfaatkan method replace()

# %%
customer_df.replace({customer_df['age'].max(): 70}, inplace=True)

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.312687    50.323676  5000.693307
# std     289.265537    22.665946  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     250.000000    34.000000  2398.000000
# 50%     500.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000   500.000000  9998.000000

# %%
customer_df.replace({customer_df['age'].max(): 50}, inplace=True)

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    499.863137    49.874126  5000.693307
# std     289.615487    17.644663  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     249.000000    34.000000  2398.000000
# 50%     499.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000    80.000000  9998.000000

# %% [markdown]
# ###Menilai Data orders_df

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
order_df.isna().sum()
# Out:
# order_id         0
# customer_id      0
# payment          0
# order_date       0
# delivery_date    0
# dtype: int64

# %%
print("Jumlah duplikasi: ",order_df.duplicated().sum())
order_df.describe()
# Out:
# Jumlah duplikasi:  0
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# Masalah yang ada pada **order_df**
#
# *   Kolom order_date dan delivery_date menggunakan tipe data object / string, seharusnya datetime

# %% [markdown]
# ### Membersihkan order_df

# %% [markdown]
# #### Mengganti tipe data dari Object menjadi datetime

# %% [markdown]
# Untuk mengatasi masalah ini, kita akan mengganti tipe data pada kolom order_date & delivery_date menjadi datetime. Proses ini dapat dilakukan menggunakan function to_datetime() yang disediakan oleh library pandas

# %%
datetime_columns = ["order_date", "delivery_date"]

for column in datetime_columns:
  order_df[column] = pd.to_datetime(order_df[column])

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# ### Menilai product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.2+ KB

# %%
print("Jumlah duplikasi: ",product_df.duplicated().sum())
product_df.describe()
# Out:
# Jumlah duplikasi:  6
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# Masalah yang ada pada product_df
#
# *  Terdapat 6 buah data yang terindikasi duplikasi

# %% [markdown]
# ### Membersihkan product_df

# %% [markdown]
# #### Menghapus data yang duplikat / sama

# %%
product_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ### Menilai Sales_df

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
print("Jumlah duplikasi: ",sales_df.duplicated().sum())
sales_df.describe()
# Out:
# Jumlah duplikasi:  0
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Masalah yang ada pada sales_df
#
# *  19 data pada kolom total_price yang NULL / Kosong

# %% [markdown]
# ### Membersihkan sales_df

# %% [markdown]
# #### Mengisi Missing Value

# %%
# Mencari data yang ada missing value
sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %%
# Filling missing value of total price with multiply price_per_unit and
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %%
# Checking if there is any missing value
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Berdasarkan beberapa masalah tersebut, kita dapat mendefinisikan beberapa pertanyaan bisnis seperti berikut.
#
# *  Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
# *  Produk apa yang paling banyak dan paling sedikit terjual?
# *  Bagaimana demografi pelanggan yang kita miliki?
# *  Kapan terakhir pelanggan melakukan transaksi?
# *  Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# *  Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Eksplorasi Data customer_df

# %% [markdown]
# Untuk mendapat intisari ringkas / rangkuman dari data customer_df

# %%
# nama data = customer_df
# metode describe itu untuk meringkas data secara statistik
# include='all' itu meringkas semua data baik huruf/kalimat (string) maupun angka (integer)
customer_df.describe(include='all')
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     499.863137           NaN                NaN    49.874126
# std      289.615487           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      249.000000           NaN                NaN    34.000000
# 50%      499.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, kita akan memperoleh informasi jumlah pelanggan sebanyak 1001 orang yang berumur di kisaran antara 20 hingga 80 tahun dengan rata-rata umur sebesar 49.87 tahun dengan standar deviasinya sebesar 17.64 tahun.

# %%
# nama data = customer_df
# metode describe itu untuk meringkas data secara statistik

customer_df.groupby(by='gender').agg({
    'customer_id': 'nunique',
    'age': ['min', 'max', 'mean', "std"]
})
# Out:
#                   customer_id age
#                       nunique min max       mean        std
# gender
# Female                    115  20  79  49.147826  16.646607
# Male                      143  20  80  51.230769  18.462635
# Prefer not to say         741  20  80  49.725437  17.644283

# %% [markdown]
# *   Berdasarkan pivot table di atas, dapat diketahui bahwa pelanggan yang kita miliki didominasi oleh jenis kelamin prefer not to say.
# *   Di lain sisi, distribusi umur mereka
# ternyata cukup mirip yaitu berkisar antara 20 hingga 80 tahun

# %%
customer_df.groupby(by='city').customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
customer_df.groupby(by='state').customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               123
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# *  Berdasarkan hasil di atas, dapat dilihat bahwa persebaran pelanggan kita cukup merata pada setiap kota dan negara bagian.
# *  Pelanggan kita paling banyak berada di kota East Aidan, East Sophia, dan New Ava dengan jumlah masing-masing tiga pelanggan.
# *  Selain itu, pelanggan kita paling banyak berasal dari negara bagian South Australia.

# %% [markdown]
# ## Eksplorasi Data order_df

# %%
delivery_time = order_df['delivery_date'] - order_df['order_date']
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
order_df['delivery_time (days)'] = round(delivery_time/86400)

# %%
display(order_df)
# Out:
#      order_id  customer_id  payment order_date delivery_date  \
# 0           1           64    30811 2021-08-30    2021-09-24
# 1           2          473    50490 2021-02-03    2021-02-13
# 2           3          774    46763 2021-10-08    2021-11-03
# 3           4          433    39782 2021-05-06    2021-05-19
# 4           5          441    14719 2021-03-23    2021-03-24
# ..        ...          ...      ...        ...           ...
# 995       996          345    37843 2021-01-13    2021-02-02
# 996       997          346    53831 2021-01-18    2021-01-31
# 997       998          407    53308 2021-05-05    2021-05-21
# 998       999          428    31643 2021-06-15    2021-07-12
# 999      1000          896    27836 2021-04-07    2021-04-24
#
#      delivery_time (days)
# 0                    25.0
# 1                    10.0
# 2                    26.0
# 3                    13.0
# 4                     1.0
# ..                    ...
# 995                  20.0
# ...

# %%
order_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time (days)
# count                 1000           1000.000000
# mean   2021-06-10 20:31:12             14.078000
# min    2021-01-03 00:00:00              1.000000
# 25%    2021-03-28 00:00:00              8.000000
# 50%    2021-06-11 12:00:00             14.000000
# ...

# %% [markdown]
# ## Eksplorasi Data order_df dan customer_df

# %% [markdown]
# Buat kolom baru bernama Status, Aktif ketika customer_id terdeteksi pada kolom order_df dan sebaliknya

# %%
customer_id_in_order_df = order_df.customer_id.tolist()
customer_df["status"] = customer_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_order_df else "Non Active")
customer_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 50            51      fulan 51  Prefer not to say   52
# 547          547     fulan 547             Female   69
# 147          148     fulan 148  Prefer not to say   53
# 79            80      fulan 80  Prefer not to say   65
# 258          259     fulan 259  Prefer not to say   78
#
#                     home_address  zip_code                   city  \
# 50         59 Hand ManorApt. 544      6322          South Evaport
# 547       4159 Abby MallApt. 142      7510            New Elibury
# 147  338 Mckenzie PlaceSuite 622      6527  North Scarlettborough
# 79        516 Grant RunSuite 000      6903             Port Mason
# 258   205 Bailey IslandSuite 339       752              Kingmouth
#
#                   state    country      status
# 50   Northern Territory  Australia      Active
# 547  Northern Territory  Australia  Non Active
# 147  Northern Territory  Australia      Active
# ...

# %%
customer_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        618
# Non Active    383
# Name: customer_id, dtype: int64

# %% [markdown]
# Seperti yang terlihat pada pivot table di atas, terdapat cukup banyak pelanggan yang belum pernah melakukan transaksi sebelumnya. Ini tentunya merupakan kabar buruk bagi kita karena hampir 30% pelanggan kita belum pernah melakukan order sebelumnya.

# %% [markdown]
# ### Join tabel order_df dan customer_df dengan mode left join.

# %%
order_customer_df = pd.merge(
    left = order_df,
    right = customer_df,
    how = "left",
    left_on = "customer_id",
    right_on = "customer_id"
)
order_customer_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  \
# 0         1           64    30811 2021-08-30    2021-09-24
# 1         2          473    50490 2021-02-03    2021-02-13
# 2         3          774    46763 2021-10-08    2021-11-03
# 3         4          433    39782 2021-05-06    2021-05-19
# 4         5          441    14719 2021-03-23    2021-03-24
#
#    delivery_time (days) customer_name             gender   age  \
# 0                  25.0      fulan 64  Prefer not to say  75.0
# 1                  10.0     fulan 473               Male  61.0
# 2                  26.0     fulan 774  Prefer not to say  34.0
# 3                  13.0     fulan 433  Prefer not to say  46.0
# 4                   1.0     fulan 441  Prefer not to say  53.0
#
#                     home_address  zip_code                city  \
# 0      4927 Alice MeadowApt. 960    7787.0      Sanfordborough
# 1  531 Schmitt BoulevardApt. 010    1744.0             Annaton
# ...

# %% [markdown]
# ### Jumlah Order berdasarkan kota

# %%
order_customer_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2          West Kai         5
# 3        O'keefeton         5
# 4          East Max         5
# 5         Lake Rose         5
# 6          Rubyfort         5
# 7  Port Hannahburgh         5
# 8         Kiehnfurt         4
# 9        Lake Jesse         4

# %% [markdown]
# berdasarkan hasil tersebut, diketahui bahwa kota Jordanside dan New Ava merupakan dua kota yang memiliki jumlah order terbanyak.

# %% [markdown]
# ### Jumlah Order berdasarkan state

# %%
order_customer_df.groupby(by="state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                           state  order_id
# 0               South Australia       148
# 1                    Queensland       139
# 2               New South Wales       130
# 3             Western Australia       129
# 4  Australian Capital Territory       118
# 5                      Victoria       118
# 6                      Tasmania       112
# 7            Northern Territory       106

# %% [markdown]
# South Australia merupakan state yang paling banyak melakukan order

# %% [markdown]
# ### Jumlah order berdasarkan gender

# %%
order_customer_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#               gender  order_id
# 0  Prefer not to say       725
# 1             Female       139
# 2               Male       136

# %% [markdown]
# kebanyakan order dilakukan oleh pelanggan yang berjenis kelamin prefer not to say

# %% [markdown]
# ### Jumlah order berdasarkan kelompok usia

# %%
order_customer_df["age_group"] = order_customer_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))
order_customer_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     682
# Seniors    227
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# pelanggan yang paling banyak melakukan order berasal dari kelompok usia Adults.

# %% [markdown]
# ## Eksplorasi Data product_df dan sales_df

# %%
product_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                   description
# ...

# %% [markdown]
# Insight yang didapat dari product_df.describe ialah harga barang yang dijual berkisar antara 90 dolar hingga 119 dolar.

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Insight yang didapatkan dari sales_df yaitu pelanggan paling banyak membeli 3 buah barang dalam satu jenis produk dengan tital harga sebesar 357 dolar

# %% [markdown]
# ### Mencari harga tertinggi dan terendah dari product_df

# %%
product_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 704          698       Jacket        Parka    L  violet    119        53
# 671          665       Jacket        Parka   XS     red    119        65
# 698          692       Jacket        Parka    M  indigo    119        66
# 699          693       Jacket        Parka    L  indigo    119        44
# 700          694       Jacket        Parka   XL  indigo    119        78
# ...          ...          ...          ...  ...     ...    ...       ...
# 1225        1219     Trousers      Pleated   XL  indigo     90        45
# 1226        1220     Trousers      Pleated   XS  violet     90        58
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 599          593       Jacket       Bomber    L  violet     90        68
#
#                                         description
# ...

# %% [markdown]
# Dari tabel diatas, bisa disimpulkan bahwa produk termahal ialah jaket parka berwarna violet ukuran L dan produk termurah adalah jaket bomber berwarna violet ukuran L

# %%
product_df.groupby(by="product_type").agg({
    "product_id" : "nunique",
    "quantity": "sum",
    "price" : ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
product_df.groupby(by="product_name").agg({
    "product_id" : "nunique",
    "quantity": "sum",
    "price" : ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %% [markdown]
# ### Menggabungkan table sales_df dan products_df untuk mencari produk yang paling laris

# %%
sales_product_df = pd.merge(
    left = sales_df,
    right = product_df,
    how = "left",
    left_on = "product_id",
    right_on = "product_id"
)

sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %%
sales_product_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# Tabel diatas menunjukan bahwa **Trousers** merupakan tipe produk yang palng laris. Tetapi jika dilihat dari keuntungan terbesar, **Jacket** merupakan tipe produk yang paling banyak menyumbang revenue perusahaan.

# %% [markdown]
# ### Membuat pivot table untuk melihat informasi penjualan berdasarkan nama produk

# %%
sales_product_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# ...

# %% [markdown]
# Berdasarkan pivot table diatas, diketahui bahwa produk **Denim** merupakan produk yang paling laris dan juga paling banyak menyumbang pendapatan perusahaan

# %% [markdown]
# ## Eksplorasi Data all_df

# %%
all_dataframe = pd.merge(
    left = sales_product_df,
    right = order_customer_df,
    how = "left",
    left_on = "order_id",
    right_on = "order_id"
)

all_dataframe.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender   age               home_address  zip_code  \
# 0  Prefer not to say  75.0  4927 Alice MeadowApt. 960    7787.0
# ...

# %%
all_dataframe.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum",
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               454        48355
#                              Shirt                433        44170
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %%
all_dataframe.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum",
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2391       256163
#                   Shirt               2410       247102
#                   Trousers            2430       246215

# %%
all_dataframe.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum",
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2299       245813
#           Shirt               2232       228513
#           Trousers            2273       231367
# Seniors   Jacket               783        83680
#           Shirt                737        75374
#           Trousers             770        77878
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %%
#agg() itu untuk membuat pivot table dengan lebih dari satu parameter

# %% [markdown]
# # Data Visualisation + Explanatory Data Analysis

# %% [markdown]
# ## Bagaimana **Performa Penjualan** dan **Revenue Perusahaan** dalam **Beberapa Bulan Terakhir**?

# %%
import pandas as pd

monthly_orders_df = all_dataframe.resample(rule='ME', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})

monthly_orders_df.index = pd.to_datetime(monthly_orders_df.index)
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns= {
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)

display(monthly_orders_df)
# Out:
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    97102
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597
# 5    2021-06          102   101458
# 6    2021-07          105   117170
# 7    2021-08          106   104565
# 8    2021-09           98    96526
# 9    2021-10           80    84266

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 5))
plt.plot(monthly_orders_df["order_date"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4")
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# *  Berdasarkan visualisasi di atas, dapat disimpulkan bahwa jumlah order terbanyak terjadi pada bulan Maret
# *  Selain itu, kita juga dapat melihat adanya penurunan jumlah order yang cukup signifikan pada bulan Februari, April, Mei, dan Oktober.
# * Tentunya penurunan tersebut akan berdampak pada total revenue yang diperoleh perusahaan

# %%
plt.figure(figsize = (10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["revenue"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title('Total Revenue per Month (2021)', loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# Penurunan jumlah orderan yang sangat signifikan terjadi pada bulan Februari, April, Mei, dan Oktober berdampak terhadap penurunan revenue perusahaan. Normalnya, kita harus mencari tahu penyebab terjadinya penurunan tersebut dengan mempertimbangkan banyak hal, seperti keberadaan kompetitor, campaign, dll. Namun, untuk studi kasus ini, kita tidak memiliki cukup informasi terkait hal tersebut.

# %% [markdown]
# ## Produk apa yang **paling banyak** dan **paling sedikit terjual** ?

# %%
sum_order_items_df = all_dataframe.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(10)
# Out:
#       product_name  quantity_x
# 0            Denim         535
# 1          Joggers         334
# 2  Casual Slim Fit         308
# 3          Pleated         308
# 4      Trench Coat         305
# 5      Relaxed Leg         303
# 6        Shearling         302
# 7           Puffer         299
# 8           Bomber         297
# 9         Chambray         290

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(24, 6)) # Changed ax to axes for clarity

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

# Best Performing Product
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=axes[0])
axes[0].set_ylabel(None)
axes[0].set_xlabel(None)
axes[0].set_title("Best Performing Product", loc="center", fontsize=15)
axes[0].tick_params(axis='y', labelsize=12)

# Worst Performing Product
# Jumlah produk terbanyak
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=axes[1])
axes[1].set_ylabel(None)
axes[1].set_xlabel(None)
axes[1].invert_xaxis()
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()
axes[1].set_title("Worst Performing Product", loc="center", fontsize=15)
axes[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()
# Out:
# <ipython-input-79-0329865b1a31>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=axes[0])
# <ipython-input-79-0329865b1a31>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=axes[1])

# %% [markdown]
# ## Bagaimana Demografi Pelanggan yang Kita Miliki?

# %% [markdown]
# ### Berdasarkan Gender

# %%
bygender_df = all_dataframe.groupby(by="gender").customer_id.nunique().reset_index()
bygender_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

bygender_df
# Out:
#               gender  customer_count
# 0             Female              73
# 1               Male              82
# 2  Prefer not to say             461

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y = "customer_count",
    x = "gender",
    data = bygender_df.sort_values(by = "customer_count", ascending = False),
    palette = colors
)

plt.title("Number of Customer by Gender", loc = "center", fontsize = 15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis = 'x', labelsize = 12)

plt.show()
# Out:
# <ipython-input-85-a35e60c3a025>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-85-a35e60c3a025>:3: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# Berdasarkan gambar di atas, diketahui bahwa kebanyakan pelanggan tidak bersedia untuk memberitahukan informasi terkait gender-nya.

# %% [markdown]
# ### Berdasarkan Age

# %%
byage_df = all_dataframe.groupby(by = "age_group").customer_id.nunique().reset_index()
byage_df.rename(columns = {
    "customer_id": "customer_count"
}, inplace = True)

byage_df
# Out:
#   age_group  customer_count
# 0    Adults             417
# 1   Seniors             145
# 2     Youth              55

# %%
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ["Youth", "Adults", "Seniors"])

plt.figure(figsize = (10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y = "customer_count",
    x = "age_group",
    data = byage_df.sort_values(by = "age_group", ascending = False),
    palette = colors_
)

plt.title("Number of Customer by Age", loc = "center", fontsize = 15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis = 'x', labelsize = 12)

plt.show()
# Out:
# <ipython-input-88-d1c152eafdf6>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-88-d1c152eafdf6>:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Berdasarkan States

# %%
all_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5014 entries, 0 to 5013
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sales_id              5014 non-null   int64
#  1   order_id              5014 non-null   int64
#  2   product_id            5014 non-null   int64
#  3   price_per_unit        5014 non-null   int64
#  4   quantity_x            5014 non-null   int64
#  5   total_price           5014 non-null   int64
#  6   product_type          5014 non-null   object
#  7   product_name          5014 non-null   object
#  8   size                  5014 non-null   object
#  9   colour                5014 non-null   object
#  10  price                 5014 non-null   int64
#  11  quantity_y            5014 non-null   int64
#  12  description           5014 non-null   object
#  13  customer_id           5014 non-null   int64
#  14  payment               5014 non-null   int64
# ...

# %%
byage_df = all_dataframe.groupby(by = "state").customer_id.nunique().reset_index()
byage_df.rename(columns = {
    "customer_id": "customer_count"
}, inplace = True)

byage_df
# Out:
#                           state  customer_count
# 0  Australian Capital Territory              73
# 1               New South Wales              78
# 2            Northern Territory              75
# 3                    Queensland              79
# 4               South Australia              90
# 5                      Tasmania              67
# 6                      Victoria              75
# 7             Western Australia              79

# %%
plt.figure(figsize = (10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x = "customer_count",
    y = "state",
    data = byage_df.sort_values(by = "customer_count", ascending = False),
    palette = colors_
)

plt.title("Number of Customer by States", loc = "center", fontsize = 15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis = 'y', labelsize = 12)

plt.show()
# Out:
# <ipython-input-100-9b7a70a55c28>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## RFM Analysis
# satu metode yang umum digunakan untuk melakukan segmentasi pelanggan.
#
# 3 Parameter : Recency, Frequency, Monetary
#
# *  Recency: parameter yang digunakan untuk melihat kapan terakhir seorang pelanggan melakukan transaksi.
# *  Frequency: parameter ini digunakan untuk mengidentifikasi seberapa sering seorang pelanggan melakukan transaksi.
# *  Monetary: parameter terakhir ini digunakan untuk mengidentifikasi seberapa besar revenue yang berasal dari pelanggan tersebut.
#
# berdasarkan tiga parameter tersebut, kita bisa mengidentifikasi pelanggan mana yang memiliki high value (sering melakukan transaksi dan menghasilkan revenue yang besar) dan low value

# %%
rfm_df = all_dataframe.groupby(by = "customer_id", as_index = False). agg({
    "order_date": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "total_price": "sum" # menghitung jumlah revenue yang dihasilkan
})

rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# Menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = order_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis = 1, inplace = True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# <ipython-input-104-af7d5f90629b>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# <ipython-input-104-af7d5f90629b>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# <ipython-input-104-af7d5f90629b>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
